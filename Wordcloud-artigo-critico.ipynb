# %% [markdown]
# # Script para geração de wordcloud (nuvem de palavras)

# %% [markdown]
# # Conteúdo:
# - impotar pacotes
# - ler e importar arquivo .txt
# -

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline
import nltk
from nltk.corpus import stopwords

# %%
pwd
# Out:
# 'C:\\Users\\bruno.r\\Desktop'

# %%
artigo1=open('dev.critical.txt').read()

# %%
artigo1
# Out:
# 'Development of Critical Thinking\n\nAbstract. The present paper gives the overview of the basic principles and\nstrategies for development of students’ critical thinking and reflection. Ideas of\ncontemporary teaching and methodology for development of critical thinking\n\nand reflection presented in the article are implemented in teacher training pro-\ngrams at the Estonian Centre for Engineering Pedagogy, Tallinn University of\n\nTechnology. Analysis of the qualitative research carried out among the students\nis introduced. Students evaluated strategies implemented in teaching with the\naim of developing and supporting students’ critical thinking, reflection and\nmetacognition.\nKeywords: Critical thinking  Active learning  Reflection  Methodology  Strategies  Metacognition\n1 Introduction\nEngineering has never mattered more. What engineers know, how they think and what\nthey can do are critical resources in our society today.\n\nAccording to the statement of Partnership for 21st
# ...

# %%
wc1=WordCloud()
wc1.generate(artigo1)
plt.figure(figsize=(10,10))
plt.imshow(wc1)

# %% [markdown]
# ## Código abaixo não precisa inserir. Igual ao de cima.

# %%
# Verificando as stopwords
stop = set(nltk.corpus.stopwords.words('english'))

# %%
stop
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
# Gerando nuvem de palvras sem as stop words
# Verificar se o código acima retirou as stopwords
wc1=WordCloud(stopwords=stop)
wc1.generate(artigo1)
plt.figure(figsize=(10,10))
plt.imshow(wc1)

# %%
# Sim, acredito que por default o código não pega as stopwords por ser o inglês nativo

# %%
# Mundando o plano de fundo
wc1=WordCloud(background_color='white', stopwords=)
wc1.generate(artigo1)
plt.figure(figsize=(10,10))
plt.imshow(wc1)

# %%
# gerando uma imagem da nuvme de palavras
wc1.to_file('nuvem_artigo_critical.png')
